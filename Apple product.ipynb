# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('apple_products.csv')

df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# Data type conversion
df['Sale Price'] = pd.to_numeric(df['Sale Price'])

df['Discount Percentage'] = pd.to_numeric(df['Discount Percentage'])
df['Number Of Ratings'] = pd.to_numeric(df['Number Of Ratings'])
df['Number Of Reviews'] = pd.to_numeric(df['Number Of Reviews'])
df['Star Rating'] = pd.to_numeric(df['Star Rating'])

# Feature Engineering
df['Price Difference'] = df['Mrp'] - df['Sale Price']
df['Discounted Price Ratio'] = df['Sale Price'] / df['MRP']
df['Popularity Metric'] = df['Number Of Ratings'] + df['Number Of Reviews']

# Outlier detection
df = df[(df['Sale Price'] > 0) & (df['Sale Price'] < df['MRP'] * 2)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MRP'
#
# ...
